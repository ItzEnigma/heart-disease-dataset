# %% [markdown]
# <h1 style= "color:blue;"><b>ML_DataSet</b></h1>
# ==================
# <h2 style= "color:teal;">This DataSet is 2020 annual CDC survey data of 400k adults related to their health status concerned with <b><u>HeartDisease</b></h2>
#
# <h3>The dataset contains <u>18 variables</u> (9 booleans, 5 strings and 4 decimals). In this machine learning project, "HeartDisease" can be used as the explonatory variable, but the classes are heavily unbalanced.</h3>

# %% [markdown]
# <h2 style= "color:blue;"><u>Members</u></h2>
# <h5 style= "color:darkblue;">=> Hosam<br>=> Taqi<br>=> John<br>=> Helal<br>=> Zeyad</h5>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataSet = pd.read_csv('heart_2020_cleaned.csv')

# %%
dataSet.head(10) #viewing top 10 in the dataset
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
# 5          Yes  28.87     Yes              No     No             6.0
# 6           No  21.63      No              No     No            15.0
# 7           No  31.64     Yes              No     No             5.0
# 8           No  26.45      No              No     No             0.0
# 9           No  40.69      No              No     No             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0          30.0          No  Female        55-59  White
# 1           0.0          No  Female  80 or older  White
# ...

# %%
print(dataSet.shape)
print("We find that we have 319795 Rows (Persons) & 18 Columns (Variables)")
# Out:
# (319795, 18)
# We find that we have 319795 Rows (Persons) & 18 Columns (Variables)

# %% [markdown]
# ### We find that the DataSet is unbalanced, meaning that it contains non-integer variables (Strings, Booleans, ...)

# %% [markdown]
# <h2 style= "color:blue;"><u>Problems</u></h2>
# <h4 style= "color:darkblue;">- We have no missing data</h4>
# <h4 style= "color:darkblue;">- We don't have Null Data ... but we have <u>Categorial unbalanced values</u></h4>
# <h4 style= "color:darkblue;">- Needs a proper plotting (Heatmap or any ...)</h4>
# <h4 style= "color:darkblue;">- Needs a proper Scaling</h4>
# <h4 style= "color:darkblue;">- Data Visualization and Representation</h4>
